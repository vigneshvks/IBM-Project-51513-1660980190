# %% [markdown]
# **Importing** **the** **libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  14,  56, 118],
#        [  0,   0,   0, ...,  63,  52,  10],
#        [  0,   0,   0, ...,  20,  52,  72],
#        ...,
#        [  0,   0,   0, ...,   2, 292,   2],
#        [  0,   0,   0, ...,   8, 816, 268],
#        [  0,   0,   0, ..., 928,   8, 370]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: 'that',
#  20: 'are',
#  21: '2',
#  22: 'now',
#  23: 'so',
#  24: 'not',
#  25: 'but',
#  26: 'can',
#  27: 'or',
#  28: 'do',
#  29: 'at',
#  30: 'will',
#  31: 'with',
#  32: 'get',
#  33: 'if',
#  34: "i'm",
#  35: 'be',
#  36: 'ur',
#  37: 'just',
#  38: 'no',
#  39: 'this',
#  40: 'we',
#  41: 'gt',
#  42: '4',
#  43: 'lt',
#  44: 'when',
#  45: 'up',
#  46: 'how',
#  47: 'from',
#  48: 'free',
#  49: 'ok',
#  50: 'go',
#  51: 'what',
#  52: 'all',
#  53: 'out',
#  54: 'know',
#  55: 'then',
#  56: 'good',
#  57: 'like',
#  58: 'got',
#  59: 'am',
#  60: 'was',
#  61: 'come',
#  62: 'time',
#  63: 'its',
#  64: 'only',
#  65: 'day',
#  66: 'love',
#  67: 'text',
#  68: 'want',
#  69: 'send',
#  70: 'as',
#  71: 'txt',
#  72: 'there',
#  73: 'home',
#  74: 'about',
#  75: 'he',
#  76: 'need',
#  77: 'going',
#  78: 'one',
#  79: 'by',
#  80: "i'll",
#  81: 'sorry',
#  82: 'see',
#  83: 'r',
#  84: 'back',
#  85: 'stop',
#  86: 'today',
#  87: 'she',
#  88: 'still',
#  89: 'da',
#  90: 'k',
#  91: 'lor',
#  92: 'n',
#  93: "don't",
#  94: 'take',
#  95: 'hi',
#  96: 'later',
#  97: 'been',
#  98: 'pls',
#  99: 'our',
#  100: 'think',
#  101: 'reply',
#  102: 'tell',
#  103: 'mobile',
#  104: 'new',
#  105: 'they',
#  106: 'any',
#  107: 'dont',
#  108: 'please',
#  109: 'her',
#  110: 'here',
#  111: 'ì',
#  112: 'much',
#  113: 'great',
#  114: '1',
#  115: 'week',
#  116: 'has',
#  117: 'did',
#  118: 'night',
#  119: 'some',
#  120: 'well',
#  121: 'phone',
#  122: 'hey',
#  123: 'oh',
#  124: 'hope',
#  125: 'dear',
#  126: 'too',
#  127: 'who',
#  128: 'an',
#  129: 'where',
#  130: 'more',
#  131: 'claim',
#  132: 'msg',
#  133: 'yes',
#  134: 'him',
#  135: 'happy',
#  136: 'make',
#  137: 'had',
#  138: 'give',
#  139: 'should',
#  140: 'way',
#  141: 'www',
#  142: 'd',
#  143: "it's",
#  144: 'c',
#  145: 'e',
#  146: 'number',
#  147: 'prize',
#  148: '3',
#  149: 'say',
#  150: 'work',
#  151: 'wat',
#  152: 'after',
#  153: 'message',
#  154: 'right',
#  155: 'said',
#  156: 'doing',
#  157: 'amp',
#  158: 'ask',
#  159: 'life',
#  160: 'tomorrow',
#  161: 'really',
#  162: 'why',
#  163: 'meet',
#  164: 'cash',
#  165: 'find',
#  166: 'im',
#  167: 'very',
#  168: 'them',
#  169: 'already',
#  170: 't',
#  171: 'yeah',
#  172: 'thanks',
#  173: 'miss',
#  174: 'morning',
#  175: 'last',
#  176: 'babe',
#  177: 'would',
#  178: 'lol',
#  179: 'cos',
#  180: 'win',
#  181: 'won',
#  182: 'care',
#  183: 'keep',
#  184: 'urgent',
#  185: 'contact',
#  186: 'also',
#  187: 'every',
#  188: '150p',
#  189: 'over',
#  190: 'uk',
#  191: 'first',
#  192: 'cant',
#  193: 'anything',
#  194: 'next',
#  195: 'something',
#  196: 'let',
#  197: 's',
#  198: 'pick',
#  199: 'nokia',
#  200: 'sure',
#  201: 'sent',
#  202: 'com',
#  203: 'could',
#  204: 'again',
#  205: 'wait',
#  206: 'around',
#  207: 'before',
#  208: 'min',
#  209: 'feel',
#  210: '50',
#  211: 'us',
#  212: 'even',
#  213: 'buy',
#  214: 'b',
#  215: 'off',
#  216: "i've",
#  217: 'his',
#  218: 'someone',
#  219: 'many',
#  220: 'tone',
#  221: 'went',
#  222: '5',
#  223: "can't",
#  224: 'leave',
#  225: 'thing',
#  226: 'always',
#  227: 'nice',
#  228: 'service',
#  229: 'were',
#  230: 'per',
#  231: 'which',
#  232: 'customer',
#  233: 'sleep',
#  234: 'v',
#  235: 'place',
#  236: 'gonna',
#  237: 'co',
#  238: 'wish',
#  239: 'hello',
#  240: "that's",
#  241: 'late',
#  242: 'soon',
#  243: 'down',
#  244: 'sms',
#  245: '18',
#  246: 'coming',
#  247: 'chat',
#  248: 'help',
#  249: 'money',
#  250: 'tonight',
#  251: 'name',
#  252: 'ya',
#  253: 'told',
#  254: 'waiting',
#  255: 'things',
#  256: 'wan',
#  257: 'special',
#  258: 'heart',
#  259: 'friends',
#  260: 'done',
#  261: 'fine',
#  262: 'friend',
#  263: 'haha',
#  264: 'other',
#  265: '16',
#  266: 'man',
#  267: 'yet',
#  268: 'gud',
#  269: 'dun',
#  270: 'may',
#  271: 'year',
#  272: 'ìï',
#  273: "you're",
#  274: 'people',
#  275: '6',
#  276: 'getting',
#  277: 'same',
#  278: 'x',
#  279: 'use',
#  280: '7',
#  281: 'holiday',
#  282: 'smile',
#  283: 'guaranteed',
#  284: 'thk',
#  285: 'thought',
#  286: 'few',
#  287: 'meeting',
#  288: 'mins',
#  289: 'stuff',
#  290: 'ready',
#  291: 'best',
#  292: 'talk',
#  293: 'long',
#  294: 'trying',
#  295: 'having',
#  296: 'mind',
#  297: 'house',
#  298: 'live',
#  299: 'å£1',
#  300: 'draw',
#  301: 'thats',
#  302: 'never',
#  303: 'try',
#  304: 'cs',
#  305: 'class',
#  306: 'person',
#  307: 'wk',
#  308: 'finish',
#  309: 'ill',
#  310: 'being',
#  311: 'days',
#  312: 'than',
#  313: 'check',
#  314: 'y',
#  315: "didn't",
#  316: 'lunch',
#  317: 'month',
#  318: 'lar',
#  319: 'better',
#  320: 'bit',
#  321: 'box',
#  322: 'into',
#  323: 'play',
#  324: 'receive',
#  325: 'car',
#  326: 'real',
#  327: 'because',
#  328: 'enjoy',
#  329: 'job',
#  330: 'big',
#  331: 'cost',
#  332: 'dinner',
#  333: 'line',
#  334: 'start',
#  335: 'yup',
#  336: 'nothing',
#  337: 'wanna',
#  338: 'shit',
#  339: 'ah',
#  340: '1st',
#  341: 'awarded',
#  342: 'word',
#  343: 'world',
#  344: 'chance',
#  345: 'dat',
#  346: 'maybe',
#  347: 'å£1000',
#  348: 'camera',
#  349: 'cool',
#  350: 'god',
#  351: 'eat',
#  352: 'po',
#  353: 'end',
#  354: 'jus',
#  355: 'shows',
#  356: 'lot',
#  357: 'guys',
#  358: 'watch',
#  359: 'luv',
#  360: 'forgot',
#  361: 'yo',
#  362: 'might',
#  363: '150ppm',
#  364: 'speak',
#  365: 'apply',
#  366: 'called',
#  367: 'sir',
#  368: 'wont',
#  369: 'ever',
#  370: 'office',
#  371: 'aight',
#  372: 'probably',
#  373: 'fun',
#  374: 'half',
#  375: 'guess',
#  376: 'birthday',
#  377: 'landline',
#  378: 'remember',
#  379: 'quite',
#  380: 'account',
#  381: '10',
#  382: '9',
#  383: 'offer',
#  384: 'once',
#  385: 'liao',
#  386: 'another',
#  387: 'bed',
#  388: 'does',
#  389: 'princess',
#  390: 'two',
#  391: 'wife',
#  392: 'tv',
#  393: 'shall',
#  394: '000',
#  395: 'xxx',
#  396: 'reach',
#  397: 'sat',
#  398: 'minutes',
#  399: 'll',
#  400: 'bad',
#  401: 'latest',
#  402: 'town',
#  403: 'between',
#  404: 'm',
#  405: 'enough',
#  406: 'plan',
#  407: 'hear',
#  408: 'looking',
#  409: 'sweet',
#  410: 'look',
#  411: 'sexy',
#  412: 'room',
#  413: '2nd',
#  414: 'problem',
#  415: 'ringtone',
#  416: 'actually',
#  417: 'without',
#  418: 'face',
#  419: 'shopping',
#  420: 'orange',
#  421: 'pay',
#  422: 'came',
#  423: 'asked',
#  424: 'bus',
#  425: 'kiss',
#  426: 'join',
#  427: 'part',
#  428: 'girl',
#  429: 'boy',
#  430: 'dunno',
#  431: 'watching',
#  432: 'put',
#  433: 'easy',
#  434: 'early',
#  435: 'weekend',
#  436: 'says',
#  437: 'afternoon',
#  438: 'goes',
#  439: 'hour',
#  440: 'though',
#  441: 'selected',
#  442: 'thanx',
#  443: 'dad',
#  444: 'leh',
#  445: 'evening',
#  446: 'most',
#  447: 'everything',
#  448: 'little',
#  449: "he's",
#  450: 'means',
#  451: 'video',
#  452: 'den',
#  453: 'working',
#  454: 'award',
#  455: 'wanted',
#  456: 'rate',
#  457: 'tmr',
#  458: 'bt',
#  459: 'texts',
#  460: 'code',
#  461: 'wot',
#  462: 'didnt',
#  463: 'g',
#  464: 'since',
#  465: 'plus',
#  466: 'entry',
#  467: 'fuck',
#  468: 'anyway',
#  469: '8',
#  470: 'must',
#  471: 'thank',
#  472: 'collection',
#  473: 'xmas',
#  474: 'dis',
#  475: 'collect',
#  476: 'worry',
#  477: 'missed',
#  478: 'plz',
#  479: 'hair',
#  480: 'those',
#  481: 'okay',
#  482: 'wake',
#  483: 'while',
#  484: 'left',
#  485: 'juz',
#  486: "there's",
#  487: 'wif',
#  488: 'attempt',
#  489: "how's",
#  490: 'details',
#  491: 'online',
#  492: 'makes',
#  493: 'de',
#  494: 'havent',
#  495: 'school',
#  496: 'decimal',
#  497: 'show',
#  498: 'true',
#  499: 'weekly',
#  500: 'yesterday',
#  501: 'book',
#  502: 'baby',
#  503: 'else',
#  504: 'tones',
#  505: 'able',
#  506: 'food',
#  507: 'mob',
#  508: 'network',
#  509: 'pa',
#  510: 'pain',
#  511: 'friendship',
#  512: 'question',
#  513: 'made',
#  514: 'making',
#  515: "won't",
#  516: 'yours',
#  517: 'update',
#  518: 'till',
#  519: 'order',
#  520: 'hav',
#  521: 'away',
#  522: 'abt',
#  523: 'calls',
#  524: 'until',
#  525: 'wen',
#  526: 'hot',
#  527: 'å£100',
#  528: 'years',
#  529: 'double',
#  530: 're',
#  531: 'missing',
#  532: 'music',
#  533: 'mail',
#  534: 'run',
#  535: 'comes',
#  536: 'eve',
#  537: 'test',
#  538: 'coz',
#  539: 'important',
#  540: '10p',
#  541: 'ard',
#  542: 'beautiful',
#  543: 'valid',
#  544: 'full',
#  545: 'tot',
#  546: 'hurt',
#  547: 'til',
#  548: 'wid',
#  549: 'games',
#  550: 'busy',
#  551: '500',
#  552: 'goin',
#  553: 'id',
#  554: 'net',
#  555: 'await',
#  556: 'sae',
#  557: 'family',
#  558: "we're",
#  559: 'both',
#  560: 'story',
#  561: 'driving',
#  562: 'bring',
#  563: 'saw',
#  564: 'times',
#  565: "''",
#  566: 'answer',
#  567: 'haf',
#  568: 'drive',
#  569: 'rite',
#  570: 'smiling',
#  571: "haven't",
#  572: 'believe',
#  573: 'set',
#  574: "c's",
#  575: 'congrats',
#  576: 'address',
#  577: "what's",
#  578: 'trip',
#  579: 'alright',
#  580: 'todays',
#  581: 'guy',
#  582: 'messages',
#  583: 'sch',
#  584: 'top',
#  585: 'feeling',
#  586: 'sleeping',
#  587: 'game',
#  588: 'calling',
#  589: 'yourself',
#  590: 'colour',
#  591: 'hours',
#  592: 'dude',
#  593: 'pub',
#  594: 'simple',
#  595: 'sad',
#  596: 'final',
#  597: 'club',
#  598: 'gift',
#  599: 'bored',
#  600: 'lets',
#  601: 'everyone',
#  602: 'gd',
#  603: 'sis',
#  604: 'these',
#  605: 'gr8',
#  606: 'touch',
#  607: 'auction',
#  608: 'either',
#  609: 'pics',
#  610: 'unsubscribe',
#  611: 'å£5000',
#  612: 'stay',
#  613: 'change',
#  614: 'whatever',
#  615: 'tomo',
#  616: 'finished',
#  617: 'lei',
#  618: 'date',
#  619: 'oso',
#  620: "we'll",
#  621: 'words',
#  622: 'http',
#  623: 'started',
#  624: 'minute',
#  625: 'okie',
#  626: 'bonus',
#  627: '8007',
#  628: 'mean',
#  629: 'shop',
#  630: 'brother',
#  631: 'delivery',
#  632: 'loving',
#  633: 'price',
#  634: 'å£2000',
#  635: 'wil',
#  636: 'company',
#  637: 'vouchers',
#  638: 'pm',
#  639: 'leaving',
#  640: 'xx',
#  641: 'treat',
#  642: 'pounds',
#  643: 'forget',
#  644: 'services',
#  645: 'charge',
#  646: 'awesome',
#  647: 'saying',
#  648: 'walk',
#  649: 'wants',
#  650: 'happened',
#  651: 'pic',
#  652: 'happen',
#  653: 'noe',
#  654: 'tried',
#  655: 'available',
#  656: 'knw',
#  657: 'poly',
#  658: 'ring',
#  659: 'anyone',
#  660: 'choose',
#  661: 'national',
#  662: 'old',
#  663: "she's",
#  664: 'girls',
#  665: 'points',
#  666: 'private',
#  667: 'type',
#  668: 'winner',
#  669: 'needs',
#  670: 'lovely',
#  671: 'close',
#  672: 'tho',
#  673: 'card',
#  674: 'news',
#  675: 'smoke',
#  676: 'email',
#  677: 'took',
#  678: 'post',
#  679: 'gone',
#  680: 'ha',
#  681: 'carlos',
#  682: 'land',
#  683: 'movie',
#  684: 'msgs',
#  685: 'weeks',
#  686: 'pobox',
#  687: '86688',
#  688: 'boytoy',
#  689: 'drop',
#  690: 'search',
#  691: 'row',
#  692: 'don',
#  693: 'lose',
#  694: 'opt',
#  695: 'nope',
#  696: 'aft',
#  697: 'voucher',
#  698: 'quiz',
#  699: 'sister',
#  700: '\x89û',
#  701: 'mobileupd8',
#  702: 'chikku',
#  703: 'mine',
#  704: 'whole',
#  705: 'fast',
#  706: 'takes',
#  707: 'dreams',
#  708: 'wkly',
#  709: 'å£500',
#  710: 'whats',
#  711: 'kind',
#  712: 'pretty',
#  713: 'secret',
#  714: 'lucky',
#  715: 'far',
#  716: 'huh',
#  717: 'dating',
#  718: 'drink',
#  719: 'each',
#  720: '30',
#  721: 'wit',
#  722: 'chennai',
#  723: 'prob',
#  724: 'visit',
#  725: '12hrs',
#  726: 'friday',
#  727: 'head',
#  728: 'second',
#  729: 'break',
#  730: 'decided',
#  731: 'taking',
#  732: 'o',
#  733: 'nite',
#  734: 'parents',
#  735: 'cause',
#  736: 'reason',
#  737: 'seeing',
#  738: 'tired',
#  739: 'statement',
#  740: 'expires',
#  741: 'park',
#  742: '08000839402',
#  743: 'alone',
#  744: 'operator',
#  745: 'frnd',
#  746: 'worth',
#  747: 'mates',
#  748: 'saturday',
#  749: 'hold',
#  750: 'congratulations',
#  751: 'sun',
#  752: 'cum',
#  753: 'college',
#  754: 'lesson',
#  755: 'info',
#  756: 'goodmorning',
#  757: 'mum',
#  758: 'angry',
#  759: 'fancy',
#  760: 'hmm',
#  761: 'welcome',
#  762: 'thinks',
#  763: "you've",
#  764: 'listen',
#  765: 'credit',
#  766: 'earlier',
#  767: 'thinking',
#  768: 'download',
#  769: 'wrong',
#  770: 'smth',
#  771: 'oredi',
#  772: 'party',
#  773: 'yr',
#  774: '750',
#  775: 'bout',
#  776: "doesn't",
#  777: 'å£250',
#  778: 'tc',
#  779: 'open',
#  780: 'christmas',
#  781: 'w',
#  782: 'light',
#  783: 'confirm',
#  784: 'ltd',
#  785: 'numbers',
#  786: 'swing',
#  787: 'identifier',
#  788: 'th',
#  789: 'motorola',
#  790: 'case',
#  791: 'press',
#  792: 'ends',
#  793: 'outside',
#  794: '100',
#  795: 'darlin',
#  796: 'heard',
#  797: 'age',
#  798: 'talking',
#  799: 'comp',
#  800: 'hand',
#  801: 'reveal',
#  802: 'unlimited',
#  803: 'together',
#  804: 'content',
#  805: 'mayb',
#  806: 'neva',
#  807: 'least',
#  808: 'charged',
#  809: 'gas',
#  810: 'mr',
#  811: 'used',
#  812: 'lots',
#  813: 'through',
#  814: 'meant',
#  815: 'hmmm',
#  816: 'their',
#  817: 'suite342',
#  818: '2lands',
#  819: 'phones',
#  820: 'å£2',
#  821: 'felt',
#  822: 'yar',
#  823: 'ass',
#  824: 'side',
#  825: 'project',
#  826: 'bslvyl',
#  827: 'sunday',
#  828: 'sex',
#  829: 'mah',
#  830: 'complimentary',
#  831: 'truth',
#  832: 'feels',
#  833: 'log',
#  834: 'enter',
#  835: 'happiness',
#  836: 'sea',
#  837: 'india',
#  838: 'red',
#  839: '800',
#  840: 'un',
#  841: 'difficult',
#  842: 'sounds',
#  843: 'laptop',
#  844: "'",
#  845: 'hit',
#  846: 'plans',
#  847: 'hows',
#  848: 'knew',
#  849: 'fri',
#  850: 'frm',
#  851: 'savamob',
#  852: 'offers',
#  853: 'å£3',
#  854: 'extra',
#  855: 'ans',
#  856: 'std',
#  857: 'couple',
#  858: 'mu',
#  859: 'gym',
#  860: 'wow',
#  861: 'hee',
#  862: 'point',
#  863: "you'll",
#  864: 'wonder',
#  865: 'crazy',
#  866: 'freemsg',
#  867: 'f',
#  868: 'invited',
#  869: 'bank',
#  870: 'own',
#  871: 'ugh',
#  872: 'finally',
#  873: 'sending',
#  874: 'picking',
#  875: 'police',
#  876: 'ni8',
#  877: 'slowly',
#  878: 'valued',
#  879: 'pass',
#  880: 'checking',
#  881: 'direct',
#  882: 'cut',
#  883: 'caller',
#  884: '03',
#  885: 'fr',
#  886: 'die',
#  887: 'mom',
#  888: 'lost',
#  889: 'hungry',
#  890: 'etc',
#  891: 'met',
#  892: 'blood',
#  893: 'ten',
#  894: 'tel',
#  895: 'ago',
#  896: '0800',
#  897: 'comin',
#  898: 'surprise',
#  899: '11',
#  900: 'fucking',
#  901: 'read',
#  902: 'luck',
#  903: 'reading',
#  904: 'mobiles',
#  905: 'reached',
#  906: 'exam',
#  907: '2003',
#  908: 'redeemed',
#  909: '04',
#  910: 'rs',
#  911: 'callertune',
#  912: 'telling',
#  913: 'yep',
#  914: 'tonite',
#  915: 'grins',
#  916: '87066',
#  917: 'snow',
#  918: 'drugs',
#  919: 'dnt',
#  920: 'different',
#  921: 'gettin',
#  922: 'wonderful',
#  923: 'hard',
#  924: 'st',
#  925: 'na',
#  926: 'move',
#  927: 'å£350',
#  928: 'match',
#  929: 'rates',
#  930: 'admirer',
#  931: 'uncle',
#  932: 'understand',
#  933: 'ldn',
#  934: 'bill',
#  935: '12',
#  936: 'shower',
#  937: "i'd",
#  938: 'call2optout',
#  939: 'nt',
#  940: 'whenever',
#  941: 'poor',
#  942: 'moment',
#  943: 'warm',
#  944: 'area',
#  945: 'abiola',
#  946: 'terms',
#  947: 'sony',
#  948: 'player',
#  949: '08000930705',
#  950: 'father',
#  951: 'wana',
#  952: 'stupid',
#  953: 'asap',
#  954: 'gotta',
#  955: 'slow',
#  956: 'gave',
#  957: 'semester',
#  958: 'ringtones',
#  959: 'clean',
#  960: 'dream',
#  961: 'pray',
#  962: 'usual',
#  963: 'study',
#  964: 'b4',
#  965: 'kids',
#  966: 'frnds',
#  967: 'found',
#  968: 'within',
#  969: 'bath',
#  970: 'anytime',
#  971: 'å£10',
#  972: 'sell',
#  973: 'mate',
#  974: 'via',
#  975: 'almost',
#  976: 'ntt',
#  977: 'computer',
#  978: '150',
#  979: 'ice',
#  980: 'correct',
#  981: 'march',
#  982: 'txts',
#  983: 'valentines',
#  984: 'copy',
#  985: 'catch',
#  986: 'nyt',
#  987: 'kate',
#  988: 'kinda',
#  989: 'sunshine',
#  990: 'starts',
#  991: 'sofa',
#  992: "wasn't",
#  993: 'rain',
#  994: 'wap',
#  995: 'doin',
#  996: 'rakhesh',
#  997: 'itself',
#  998: 'entered',
#  999: 'somebody',
#  1000: 'lover',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           263680
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 318,921
# Trainable params: 318,921
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 16s 395ms/step - loss: 0.4500 - accuracy: 0.8585 - val_loss: 0.2516 - val_accuracy: 0.8745
# Epoch 2/10
# 30/30 [==============================] - 15s 507ms/step - loss: 0.1689 - accuracy: 0.9549 - val_loss: 0.0910 - val_accuracy: 0.9778

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0902 - accuracy: 0.9773

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.090
#   Accuracy: 0.977
