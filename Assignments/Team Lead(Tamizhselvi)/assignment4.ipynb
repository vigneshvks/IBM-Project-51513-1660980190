# %% [markdown]
# **Importing** **the** **libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  43, 486,  42],
#        [  0,   0,   0, ..., 103, 530,  70],
#        [  0,   0,   0, ..., 128,  11, 208],
#        ...,
#        [  0,   0,   0, ...,  52,  81, 338],
#        [  0,   0,   0, ..., 543,   8, 108],
#        [  0,   0,   0, ..., 151,   9, 175]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'or',
#  27: 'at',
#  28: 'do',
#  29: 'can',
#  30: 'ur',
#  31: 'with',
#  32: 'get',
#  33: "i'm",
#  34: 'will',
#  35: 'be',
#  36: 'if',
#  37: 'no',
#  38: 'just',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'gt',
#  43: 'lt',
#  44: 'up',
#  45: 'ok',
#  46: 'when',
#  47: 'go',
#  48: 'from',
#  49: 'free',
#  50: 'how',
#  51: 'all',
#  52: 'out',
#  53: 'what',
#  54: 'know',
#  55: 'like',
#  56: 'then',
#  57: 'am',
#  58: 'got',
#  59: 'good',
#  60: 'day',
#  61: 'was',
#  62: 'only',
#  63: 'come',
#  64: 'its',
#  65: 'time',
#  66: 'love',
#  67: 'there',
#  68: 'text',
#  69: 'he',
#  70: 'send',
#  71: 'want',
#  72: 'txt',
#  73: 'as',
#  74: 'by',
#  75: 'one',
#  76: 'need',
#  77: "i'll",
#  78: 'lor',
#  79: 'about',
#  80: 'home',
#  81: 'stop',
#  82: 'sorry',
#  83: 'going',
#  84: 'see',
#  85: 'r',
#  86: 'back',
#  87: 'still',
#  88: 'today',
#  89: 'our',
#  90: 'da',
#  91: 'n',
#  92: 'she',
#  93: 'reply',
#  94: 'k',
#  95: 'her',
#  96: 'any',
#  97: 'later',
#  98: 'hi',
#  99: 'take',
#  100: 'mobile',
#  101: 'been',
#  102: 'tell',
#  103: 'please',
#  104: "don't",
#  105: 'new',
#  106: 'dont',
#  107: 'week',
#  108: 'here',
#  109: 'think',
#  110: 'they',
#  111: 'ì',
#  112: 'pls',
#  113: 'well',
#  114: 'some',
#  115: 'dear',
#  116: 'has',
#  117: 'great',
#  118: '1',
#  119: 'did',
#  120: 'who',
#  121: 'phone',
#  122: 'claim',
#  123: 'night',
#  124: 'more',
#  125: 'hope',
#  126: 'him',
#  127: 'oh',
#  128: 'where',
#  129: 'msg',
#  130: 'too',
#  131: 'an',
#  132: 'happy',
#  133: 'hey',
#  134: 'much',
#  135: 'way',
#  136: 'www',
#  137: 'yes',
#  138: "it's",
#  139: 'make',
#  140: 'd',
#  141: 'had',
#  142: 'give',
#  143: 'should',
#  144: 'prize',
#  145: 'work',
#  146: 'after',
#  147: 'message',
#  148: 'number',
#  149: 'e',
#  150: 'c',
#  151: 'wat',
#  152: 'say',
#  153: 'cash',
#  154: 'right',
#  155: 'doing',
#  156: 'said',
#  157: 'tomorrow',
#  158: 'already',
#  159: 'life',
#  160: 'yeah',
#  161: 'meet',
#  162: 'thanks',
#  163: 'miss',
#  164: 'babe',
#  165: 'really',
#  166: 'amp',
#  167: '3',
#  168: 'them',
#  169: 'why',
#  170: 'cos',
#  171: 'ask',
#  172: 'would',
#  173: 'im',
#  174: 'find',
#  175: 'lol',
#  176: 'last',
#  177: 'win',
#  178: 'also',
#  179: 'uk',
#  180: 'let',
#  181: 't',
#  182: 'sure',
#  183: 'very',
#  184: 'every',
#  185: 'anything',
#  186: 'com',
#  187: 'won',
#  188: 'pick',
#  189: 'morning',
#  190: 'urgent',
#  191: "i've",
#  192: '150p',
#  193: 'something',
#  194: 'b',
#  195: 'care',
#  196: 'contact',
#  197: 'us',
#  198: 'before',
#  199: 'nokia',
#  200: 'again',
#  201: 'feel',
#  202: 'keep',
#  203: 'over',
#  204: 'sent',
#  205: 'buy',
#  206: '5',
#  207: 'thing',
#  208: 'went',
#  209: 'many',
#  210: 'which',
#  211: 'leave',
#  212: 'soon',
#  213: 'next',
#  214: 'nice',
#  215: 'sleep',
#  216: 'cant',
#  217: 'off',
#  218: 'co',
#  219: 'min',
#  220: 'first',
#  221: 'tone',
#  222: 'around',
#  223: 'could',
#  224: "can't",
#  225: 'tonight',
#  226: 'place',
#  227: '50',
#  228: 'wait',
#  229: 'gud',
#  230: 'late',
#  231: 'always',
#  232: 's',
#  233: 'per',
#  234: 'service',
#  235: 'x',
#  236: 'sms',
#  237: 'things',
#  238: 'his',
#  239: 'were',
#  240: 'friends',
#  241: 'even',
#  242: 'waiting',
#  243: 'money',
#  244: 'someone',
#  245: 'other',
#  246: 'customer',
#  247: 'ya',
#  248: 'dun',
#  249: 'gonna',
#  250: 'help',
#  251: 'ìï',
#  252: 'v',
#  253: 'wan',
#  254: 'down',
#  255: 'wish',
#  256: 'told',
#  257: 'haha',
#  258: 'use',
#  259: '18',
#  260: 'same',
#  261: 'may',
#  262: 'done',
#  263: 'coming',
#  264: 'getting',
#  265: 'try',
#  266: 'special',
#  267: 'chat',
#  268: "you're",
#  269: 'people',
#  270: 'stuff',
#  271: 'better',
#  272: 'best',
#  273: 'name',
#  274: '6',
#  275: 'fine',
#  276: 'friend',
#  277: '16',
#  278: 'hello',
#  279: 'guaranteed',
#  280: 'thk',
#  281: 'heart',
#  282: 'year',
#  283: 'yet',
#  284: "that's",
#  285: 'holiday',
#  286: 'thought',
#  287: 'man',
#  288: 'mins',
#  289: 'cs',
#  290: 'y',
#  291: 'talk',
#  292: 'smile',
#  293: 'draw',
#  294: 'class',
#  295: "didn't",
#  296: 'trying',
#  297: 'job',
#  298: 'never',
#  299: 'ill',
#  300: 'lunch',
#  301: 'house',
#  302: '7',
#  303: 'mind',
#  304: 'play',
#  305: 'meeting',
#  306: 'ready',
#  307: 'bit',
#  308: 'than',
#  309: 'å£1',
#  310: 'finish',
#  311: 'end',
#  312: 'dinner',
#  313: 'cool',
#  314: 'lot',
#  315: 'awarded',
#  316: 'check',
#  317: 'few',
#  318: 'line',
#  319: 'days',
#  320: 'wanna',
#  321: 'chance',
#  322: 'dat',
#  323: 'yo',
#  324: 'car',
#  325: 'person',
#  326: 'because',
#  327: 'sir',
#  328: 'account',
#  329: 'eat',
#  330: 'half',
#  331: 'god',
#  332: '1st',
#  333: 'having',
#  334: 'world',
#  335: 'live',
#  336: 'being',
#  337: 'thats',
#  338: 'wk',
#  339: 'word',
#  340: 'liao',
#  341: 'yup',
#  342: 'guess',
#  343: 'probably',
#  344: 'receive',
#  345: 'lar',
#  346: 'month',
#  347: 'enjoy',
#  348: 'watching',
#  349: 'big',
#  350: 'might',
#  351: 'long',
#  352: 'latest',
#  353: 'camera',
#  354: 'å£1000',
#  355: 'speak',
#  356: 'another',
#  357: 'two',
#  358: 'quite',
#  359: 'den',
#  360: 'watch',
#  361: 'ever',
#  362: 'shit',
#  363: 'real',
#  364: 'ah',
#  365: 'actually',
#  366: 'birthday',
#  367: 'cost',
#  368: 'start',
#  369: 'bed',
#  370: 'shows',
#  371: 'landline',
#  372: 'tv',
#  373: 'early',
#  374: 'between',
#  375: 'problem',
#  376: '150ppm',
#  377: 'maybe',
#  378: 'guys',
#  379: 'video',
#  380: 'apply',
#  381: 'nothing',
#  382: 'box',
#  383: 'reach',
#  384: 'part',
#  385: 'forgot',
#  386: 'once',
#  387: 'shall',
#  388: 'orange',
#  389: 'weekend',
#  390: 'luv',
#  391: 'remember',
#  392: 'minutes',
#  393: '10',
#  394: 'rate',
#  395: 'offer',
#  396: 'bt',
#  397: 'kiss',
#  398: 'wont',
#  399: 'plan',
#  400: 'face',
#  401: 'sweet',
#  402: 'room',
#  403: 'xxx',
#  404: 'tmr',
#  405: 'little',
#  406: 'thanx',
#  407: 'into',
#  408: 'll',
#  409: 'shopping',
#  410: 'easy',
#  411: 'fun',
#  412: 'bad',
#  413: 'everything',
#  414: 'didnt',
#  415: 'bus',
#  416: 'until',
#  417: 'ringtone',
#  418: 'made',
#  419: 'baby',
#  420: 'sat',
#  421: 'without',
#  422: "he's",
#  423: 'pay',
#  424: 'called',
#  425: 'missing',
#  426: 'working',
#  427: 'put',
#  428: 'po',
#  429: 'leh',
#  430: 'dis',
#  431: 'does',
#  432: 'fuck',
#  433: 'pa',
#  434: '000',
#  435: 'girl',
#  436: 'town',
#  437: 'wife',
#  438: 'office',
#  439: 'afternoon',
#  440: 'enough',
#  441: '2nd',
#  442: 'boy',
#  443: 'xmas',
#  444: 'wif',
#  445: '9',
#  446: 'anyway',
#  447: 'evening',
#  448: 'look',
#  449: 'okay',
#  450: 'looking',
#  451: 'most',
#  452: "how's",
#  453: 'jus',
#  454: 'plz',
#  455: 'hour',
#  456: 'code',
#  457: 'dad',
#  458: 'though',
#  459: 'g',
#  460: 'sexy',
#  461: 'away',
#  462: 'says',
#  463: 'means',
#  464: 'missed',
#  465: 'mail',
#  466: 'tones',
#  467: 'm',
#  468: 'calls',
#  469: 'dunno',
#  470: 'left',
#  471: 'selected',
#  472: 'join',
#  473: 'thank',
#  474: 'hear',
#  475: 'aight',
#  476: 'texts',
#  477: 'asked',
#  478: 'collect',
#  479: 'those',
#  480: '8',
#  481: 'making',
#  482: 'details',
#  483: 'entry',
#  484: 'weekly',
#  485: 'show',
#  486: 'decimal',
#  487: 'pain',
#  488: 'must',
#  489: 'school',
#  490: 'price',
#  491: 'makes',
#  492: 'till',
#  493: 'bring',
#  494: 'network',
#  495: 'havent',
#  496: 'princess',
#  497: 'valid',
#  498: 'able',
#  499: 'collection',
#  500: 'change',
#  501: 'wot',
#  502: 'messages',
#  503: 'either',
#  504: 'abt',
#  505: 'true',
#  506: 'important',
#  507: 'juz',
#  508: '500',
#  509: 'top',
#  510: 'since',
#  511: 'update',
#  512: 'delivery',
#  513: 'wake',
#  514: 'å£100',
#  515: 'run',
#  516: 'yesterday',
#  517: 'de',
#  518: 'gift',
#  519: 'hair',
#  520: 'goes',
#  521: 'these',
#  522: 'while',
#  523: 'hav',
#  524: 'wen',
#  525: 'net',
#  526: 'food',
#  527: "there's",
#  528: 'wanted',
#  529: 'double',
#  530: 're',
#  531: 'oso',
#  532: 'calling',
#  533: 'came',
#  534: 'times',
#  535: 'plus',
#  536: 'tried',
#  537: '10p',
#  538: 'mob',
#  539: 'ard',
#  540: 'til',
#  541: 'game',
#  542: 'else',
#  543: 'stay',
#  544: 'both',
#  545: 'online',
#  546: 'haf',
#  547: 'music',
#  548: 'hurt',
#  549: 'saw',
#  550: 'family',
#  551: 'years',
#  552: 'feeling',
#  553: 'attempt',
#  554: 'book',
#  555: 'answer',
#  556: 'å£2000',
#  557: 'coz',
#  558: 'dude',
#  559: 'friendship',
#  560: 'trip',
#  561: 'drive',
#  562: 'national',
#  563: 'hot',
#  564: 'id',
#  565: 'charge',
#  566: 'yourself',
#  567: 'aft',
#  568: 'together',
#  569: 'shop',
#  570: 'alright',
#  571: 'worry',
#  572: 'sae',
#  573: "haven't",
#  574: 'believe',
#  575: 'beautiful',
#  576: 'lei',
#  577: 'bored',
#  578: 'smiling',
#  579: 'colour',
#  580: 'comes',
#  581: 'test',
#  582: 'old',
#  583: 'wil',
#  584: 'question',
#  585: 'award',
#  586: 'ring',
#  587: 'lose',
#  588: 'movie',
#  589: 'chikku',
#  590: 'sad',
#  591: 'angry',
#  592: 'busy',
#  593: 'bonus',
#  594: 'await',
#  595: 'sch',
#  596: 'driving',
#  597: 'leaving',
#  598: 'wants',
#  599: "won't",
#  600: 'å£500',
#  601: 'yours',
#  602: 'poly',
#  603: 'everyone',
#  604: 'sleeping',
#  605: 'thinking',
#  606: 'pounds',
#  607: 'row',
#  608: 'words',
#  609: 'full',
#  610: 'alone',
#  611: 'touch',
#  612: 'news',
#  613: 'nite',
#  614: 'mean',
#  615: 'huh',
#  616: 'wid',
#  617: 'finished',
#  618: 'auction',
#  619: 'todays',
#  620: 'voucher',
#  621: 'http',
#  622: 'awesome',
#  623: 'okie',
#  624: 'guy',
#  625: 'set',
#  626: 'lots',
#  627: 'took',
#  628: 'noe',
#  629: 'each',
#  630: "we're",
#  631: 'second',
#  632: '8007',
#  633: 'å£5000',
#  634: 'story',
#  635: 'vouchers',
#  636: 'goin',
#  637: 'order',
#  638: 'pics',
#  639: 'taking',
#  640: 'opt',
#  641: 'neva',
#  642: 'tomo',
#  643: 'drink',
#  644: 'services',
#  645: '86688',
#  646: 'saying',
#  647: 'rite',
#  648: 'kind',
#  649: 'club',
#  650: 'tho',
#  651: 'tot',
#  652: 'gd',
#  653: "she's",
#  654: 'treat',
#  655: 'land',
#  656: '12hrs',
#  657: 'address',
#  658: 'happen',
#  659: 'walk',
#  660: '750',
#  661: 'started',
#  662: 'worth',
#  663: 'drop',
#  664: 'email',
#  665: 'games',
#  666: 'final',
#  667: 'pic',
#  668: 'date',
#  669: 'frnd',
#  670: 'lets',
#  671: "you've",
#  672: 'carlos',
#  673: 'saturday',
#  674: 'hand',
#  675: 'don',
#  676: 'gr8',
#  677: 'pm',
#  678: 'open',
#  679: 'loving',
#  680: 'sounds',
#  681: 'company',
#  682: 'pub',
#  683: 'xx',
#  684: 'eve',
#  685: 'fast',
#  686: 'winner',
#  687: 'lesson',
#  688: 'lucky',
#  689: 'pretty',
#  690: 'lovely',
#  691: 'far',
#  692: "''",
#  693: 'minute',
#  694: "we'll",
#  695: "c's",
#  696: 'available',
#  697: 'close',
#  698: 'oredi',
#  699: 'head',
#  700: 'boytoy',
#  701: 'pobox',
#  702: 'unsubscribe',
#  703: 'hours',
#  704: 'points',
#  705: 'anyone',
#  706: 'card',
#  707: 'dreams',
#  708: 'w',
#  709: 'needs',
#  710: 'found',
#  711: 'used',
#  712: 'search',
#  713: 'å£3',
#  714: 'brother',
#  715: 'wonderful',
#  716: 'player',
#  717: 'bank',
#  718: 'smth',
#  719: 'congratulations',
#  720: 'type',
#  721: '11',
#  722: 'quiz',
#  723: "doesn't",
#  724: 'college',
#  725: 'operator',
#  726: '\x89û',
#  727: '100',
#  728: 'mate',
#  729: 'msgs',
#  730: 'least',
#  731: 'nt',
#  732: 'cause',
#  733: 'decided',
#  734: 'secret',
#  735: "what's",
#  736: 'dating',
#  737: 'smoke',
#  738: 'ha',
#  739: 'frm',
#  740: 'sis',
#  741: 'sun',
#  742: 'project',
#  743: 'happened',
#  744: 'knw',
#  745: 'whats',
#  746: 'download',
#  747: 'welcome',
#  748: 'txts',
#  749: 'sea',
#  750: 'hows',
#  751: "you'll",
#  752: 'tel',
#  753: 'lost',
#  754: 'suite342',
#  755: '2lands',
#  756: 'point',
#  757: 'march',
#  758: 'mobileupd8',
#  759: 'etc',
#  760: 'age',
#  761: 'seeing',
#  762: 'case',
#  763: 'choose',
#  764: 'anytime',
#  765: 'goodmorning',
#  766: 'unlimited',
#  767: '30',
#  768: 'finally',
#  769: 'congrats',
#  770: 'camcorder',
#  771: '08000930705',
#  772: 'mates',
#  773: 'enter',
#  774: 'private',
#  775: 'statement',
#  776: 'expires',
#  777: 'log',
#  778: 'forget',
#  779: 'mine',
#  780: 'yr',
#  781: 'thinks',
#  782: 'mayb',
#  783: 'offers',
#  784: 'hard',
#  785: 'crazy',
#  786: 'gone',
#  787: 'takes',
#  788: 'reason',
#  789: 'savamob',
#  790: 'bout',
#  791: 'sex',
#  792: 'outside',
#  793: 'india',
#  794: 'friday',
#  795: '20',
#  796: 'fri',
#  797: 'visit',
#  798: 'balance',
#  799: 'currently',
#  800: 'seen',
#  801: 'red',
#  802: 'wrong',
#  803: 'area',
#  804: 'park',
#  805: 'call2optout',
#  806: 'parents',
#  807: 'correct',
#  808: 'almost',
#  809: 'darlin',
#  810: 'press',
#  811: 'listen',
#  812: 'side',
#  813: 'ends',
#  814: 'o',
#  815: 'å£250',
#  816: 'felt',
#  817: "'",
#  818: 'hold',
#  819: 'break',
#  820: 'telling',
#  821: 'extra',
#  822: 'identifier',
#  823: 'hit',
#  824: 'die',
#  825: 'sister',
#  826: 'caller',
#  827: 'chennai',
#  828: 'stupid',
#  829: 'bslvyl',
#  830: 'their',
#  831: 'ni8',
#  832: 'earlier',
#  833: 'hmm',
#  834: 'prob',
#  835: 'gotta',
#  836: 'fone',
#  837: 'credit',
#  838: 'wkly',
#  839: 'mum',
#  840: 'via',
#  841: 'complimentary',
#  842: 'gas',
#  843: 'ans',
#  844: '08000839402',
#  845: 'na',
#  846: 'nyt',
#  847: 'christmas',
#  848: 'dream',
#  849: 'grins',
#  850: 'slow',
#  851: 'ipod',
#  852: 'knew',
#  853: 'ltd',
#  854: 'phones',
#  855: 'charged',
#  856: 'b4',
#  857: 'picking',
#  858: 'support',
#  859: 'mrng',
#  860: 'st',
#  861: 'move',
#  862: 'nope',
#  863: 'ex',
#  864: 'exam',
#  865: 'snow',
#  866: 'f',
#  867: 'mu',
#  868: 'couple',
#  869: 'happiness',
#  870: 'whatever',
#  871: 'remove',
#  872: 'asking',
#  873: 'light',
#  874: 'wit',
#  875: 'whenever',
#  876: 'hmmm',
#  877: 'ass',
#  878: 'luck',
#  879: 'mom',
#  880: 'fancy',
#  881: 'blue',
#  882: 'dnt',
#  883: 'within',
#  884: 'rs',
#  885: '87066',
#  886: '2003',
#  887: '800',
#  888: 'un',
#  889: 'comp',
#  890: 'freemsg',
#  891: '03',
#  892: 'information',
#  893: 'motorola',
#  894: 'tired',
#  895: 'talking',
#  896: 'fucking',
#  897: 'course',
#  898: 'confirm',
#  899: 'mr',
#  900: 'info',
#  901: 'post',
#  902: 'frnds',
#  903: 'gal',
#  904: 'energy',
#  905: 'kate',
#  906: 'tc',
#  907: 'england',
#  908: 'wine',
#  909: "wasn't",
#  910: 'rock',
#  911: 'w1j6hl',
#  912: 'questions',
#  913: 'poor',
#  914: 'wishing',
#  915: 'father',
#  916: 'loads',
#  917: 'ugh',
#  918: 'girls',
#  919: 'eh',
#  920: 'wonder',
#  921: 'crave',
#  922: 'darren',
#  923: 'abiola',
#  924: 'uncle',
#  925: '12',
#  926: 'yar',
#  927: 'voice',
#  928: 'sunday',
#  929: 'valued',
#  930: 'å£350',
#  931: 'mm',
#  932: 'th',
#  933: 'eg',
#  934: 'orchard',
#  935: 'read',
#  936: 'weeks',
#  937: 'reward',
#  938: 'ts',
#  939: 'muz',
#  940: 'doin',
#  941: 'match',
#  942: 'different',
#  943: 'entered',
#  944: 'askd',
#  945: 'invited',
#  946: 'party',
#  947: 'pete',
#  948: 'hee',
#  949: 'cut',
#  950: 'through',
#  951: 'std',
#  952: 'fr',
#  953: 'store',
#  954: 'redeemed',
#  955: '04',
#  956: 'discount',
#  957: 'checking',
#  958: 'laptop',
#  959: 'å£2',
#  960: 'ten',
#  961: 'nah',
#  962: 'immediately',
#  963: 'meant',
#  964: 'understand',
#  965: 'ac',
#  966: 'heard',
#  967: 'worried',
#  968: 'sony',
#  969: 'film',
#  970: 'mah',
#  971: 'wap',
#  972: 'terms',
#  973: 'sound',
#  974: 'police',
#  975: 'numbers',
#  976: 'surprise',
#  977: 'reading',
#  978: 'reveal',
#  979: 'catch',
#  980: '0800',
#  981: 'monday',
#  982: 'across',
#  983: 'spend',
#  984: 'itself',
#  985: 'rain',
#  986: 'flag',
#  987: 'rakhesh',
#  988: 'warm',
#  989: 'rental',
#  990: 'hg',
#  991: 'blood',
#  992: 'street',
#  993: 'cum',
#  994: '2nite',
#  995: 'doesnt',
#  996: 'bcoz',
#  997: 'rates',
#  998: 'men',
#  999: 'pass',
#  1000: 'moment',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262848
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 318,089
# Trainable params: 318,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 16s 428ms/step - loss: 0.4925 - accuracy: 0.8427 - val_loss: 0.3475 - val_accuracy: 0.8671
# Epoch 2/10
# 30/30 [==============================] - 10s 333ms/step - loss: 0.2395 - accuracy: 0.9150 - val_loss: 0.1224 - val_accuracy: 0.9684

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1330 - accuracy: 0.9665

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.133
#   Accuracy: 0.967
